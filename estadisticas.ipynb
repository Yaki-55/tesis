# %%
import numpy as numpy
import pandas as pd
import os

# %%
period_order =[35,36,40,39,42,43,41,46,47,44,49,50,48,53,54,51,52,56,55,58,59,57,61]
all_period_order = [45,15,16,17,18,12,19,13,14,2,4,3,5,6,7,8,9,10,11,20,21,22,1,24,26,23,25,28,27,30,31,29,33,34,32,37,38,35,36,40,39,42,43,41,46,47,44,49,50,48,53,54,51,52,56,55,58,59,57,61,60]
period_order_name=["2017-2018A","2017-2018B","2017-2018V","2018-2019A","2018-2019B","2018-2019V","2019-2020A","2019-2020B","2019-2020V","2020-2021A","2020-2021B","2020-2021V","2021-2022A","2021-2022B","2021-2022V","2022-2023A","2022-2023B","2022-2023V","2023-2024A","2023-2024B","2023-2024V","2024-2025A","2024-2025B"]

# %%
def load_period_csvs_into_vars(base_directory):
    """
    Carga los archivos CSV de calificaciones organizados por periodo y carrera
    en variables globales con el formato p<periodo>.
    Cada variable p<periodo> será un diccionario, donde las claves son los nombres
    de los archivos CSV (con el formato p<periodo>c<carrera>s<semestre>) y los
    valores son DataFrames de pandas.

    Args:
        base_directory (str): La ruta base donde se encuentran las carpetas de 'Periodo_XX'.

    Returns:
        dict: Un diccionario donde cada clave es 'p<periodo>' y su valor es otro
              diccionario que contiene los DataFrames de los CSVs de ese período.
              Retorna un diccionario vacío si no se encuentran archivos.
    """
    period_data = {}

    if not os.path.exists(base_directory):
        print(f"Error: El directorio base '{base_directory}' no existe.")
        return period_data

    # Iterate over Periodo folders
    for period_folder_name in os.listdir(base_directory):
        if period_folder_name.startswith("Periodo_"):
            period_id = period_folder_name.replace("Periodo_", "")
            period_path = os.path.join(base_directory, period_folder_name)

            if os.path.isdir(period_path):
                current_period_dfs = {}

                # Iterate over Carrera folders within the period folder
                for career_folder_name in os.listdir(period_path):
                    if career_folder_name.startswith("Carrera_"):
                        career_path = os.path.join(period_path, career_folder_name)

                        if os.path.isdir(career_path):
                            for file_name in os.listdir(career_path):
                                if file_name.endswith(".csv"):
                                    csv_path = os.path.join(career_path, file_name)

                                    # Extract components for the new concise name
                                    # Example: periodo58carrera2semestre2.csv
                                    # -> p58c2s2
                                    parts = os.path.splitext(file_name)[0].split('periodo')[1].split('carrera')
                                    period_part = parts[0]
                                    career_sem_parts = parts[1].split('semestre')
                                    career_part = career_sem_parts[0]
                                    semestre_part = career_sem_parts[1]

                                    df_name = f"p{period_part}c{career_part}s{semestre_part}"

                                    try:
                                        df = pd.read_csv(csv_path)
                                        current_period_dfs[df_name] = df
                                        print(f"Cargado: {file_name} en p{period_id}['{df_name}']")
                                    except Exception as e:
                                        print(f"Error al cargar {file_name}: {e}")

                period_var_name = f"p{period_id}"
                period_data[period_var_name] = current_period_dfs
    
    if not period_data:
        print(f"No se encontraron datos de períodos en '{base_directory}'.")
        
    return period_data

# %%
period_map = {id_p: name for id_p, name in zip(period_order, period_order_name)}
period_type = {id_p: name[-1] for id_p, name in zip(period_order, period_order_name)} # A, B, o V

csv_base_folder = r"D:/TesisDB/CSV's"

# --- Cargar todos los CSVs ---
print(f"Cargando datos desde: {csv_base_folder}")
all_period_data = load_period_csvs_into_vars(csv_base_folder)

if not all_period_data:
    print("No se pudieron cargar los datos. Asegúrate de que los CSVs existan en la ruta especificada.")
    exit()

print("Datos cargados exitosamente.")

# --- Diccionario para almacenar los nombres de las carreras (para mejor legibilidad) ---
# En un escenario real, esto se obtendría de la tabla nes_carreras de la base de datos.
# Por ahora, usaremos un mock-up o lo inferiremos si es posible.
# Si tienes una manera de obtener los nombres reales de las carreras, ¡sería ideal!
# Por ejemplo: career_names = {1: "Ing. Sistemas", 2: "Lic. Administracion", ...}
# Para este análisis, usaremos los id_carrera directamente, o podríamos inferir de los nombres de los archivos.
# Vamos a crear un placeholder para nombres de carrera si no los tenemos
career_names = {}
# Podríamos intentar inferir los IDs de carrera existentes y darles un nombre genérico
# Esto es solo un ejemplo, podrías querer cargar los nombres reales desde la DB
for p_key, p_val in all_period_data.items():
    for df_key in p_val.keys():
        try:
            # df_key looks like p<period>c<carrera>s<semestre>
            carrera_id = int(df_key.split('c')[1].split('s')[0])
            if carrera_id not in career_names:
                career_names[carrera_id] = f"Carrera {carrera_id}"
        except (IndexError, ValueError):
            pass # Ignore malformed keys

print(f"\nCarreras detectadas: {career_names}")

# --- Funciones de Análisis ---

def analyze_first_sem_population(data, p_map, p_type, c_names):
    """
    Analiza la población de primer semestre por período (solo tipo 'A') y carrera.
    """
    print("\n" + "="*50)
    print("Análisis de Población en PRIMER SEMESTRE (Periodos 'A')")
    print("="*50)

    results = []
    
    # Filtrar periodos tipo 'A' y ordenarlos según period_order
    a_periods = [p_id for p_id in period_order if p_type.get(p_id) == 'A']

    for p_id in a_periods:
        period_key = f"p{p_id}"
        period_name = p_map.get(p_id, f"Periodo {p_id}")

        if period_key in data:
            print(f"\n--- {period_name} (ID: {p_id}) ---")
            period_dfs = data[period_key]
            
            # Recopilar todos los DataFrames de semestre 1 para este período
            sem1_dfs = {df_name: df for df_name, df in period_dfs.items() if df_name.endswith('s1')}

            if sem1_dfs:
                for df_name, df in sem1_dfs.items():
                    try:
                        carrera_id = int(df_name.split('c')[1].split('s')[0])
                        carrera_name = c_names.get(carrera_id, f"Carrera {carrera_id}")
                        num_students = df['matricula_hash'].nunique() # Contar matrículas únicas
                        print(f"  {carrera_name} (ID: {carrera_id}): {num_students} estudiantes en 1er semestre.")
                        results.append({
                            'Periodo_ID': p_id,
                            'Periodo_Nombre': period_name,
                            'Carrera_ID': carrera_id,
                            'Carrera_Nombre': carrera_name,
                            'Semestre': 1,
                            'Num_Estudiantes': num_students
                        })
                    except (IndexError, ValueError):
                        print(f"  Advertencia: No se pudo parsear la ID de carrera de {df_name}.")
            else:
                print(f"  No se encontraron DataFrames para el 1er semestre en este período.")
        else:
            print(f"  Datos no disponibles para el período {period_name} (ID: {p_id}).")
    
    if not results:
        print("No se encontraron datos para el 1er semestre en periodos 'A'.")
    else:
        first_sem_df = pd.DataFrame(results)
        print("\n--- Resumen General de Primer Semestre ---")
        print(first_sem_df.pivot_table(index='Carrera_Nombre', columns='Periodo_Nombre', values='Num_Estudiantes', fill_value=0))
        return first_sem_df


def analyze_tenth_sem_population(data, p_map, p_type, c_names):
    """
    Analiza la población de décimo semestre por período (solo tipo 'B') y carrera.
    """
    print("\n" + "="*50)
    print("Análisis de Población en DÉCIMO SEMESTRE (Periodos 'B')")
    print("="*50)

    results = []
    
    # Filtrar periodos tipo 'B' y ordenarlos según period_order
    b_periods = [p_id for p_id in period_order if p_type.get(p_id) == 'B']

    for p_id in b_periods:
        period_key = f"p{p_id}"
        period_name = p_map.get(p_id, f"Periodo {p_id}")

        if period_key in data:
            print(f"\n--- {period_name} (ID: {p_id}) ---")
            period_dfs = data[period_key]
            
            # Recopilar todos los DataFrames de semestre 10 para este período
            sem10_dfs = {df_name: df for df_name, df in period_dfs.items() if df_name.endswith('s10')}

            if sem10_dfs:
                for df_name, df in sem10_dfs.items():
                    try:
                        carrera_id = int(df_name.split('c')[1].split('s')[0])
                        carrera_name = c_names.get(carrera_id, f"Carrera {carrera_id}")
                        num_students = df['matricula_hash'].nunique() # Contar matrículas únicas
                        print(f"  {carrera_name} (ID: {carrera_id}): {num_students} estudiantes en 10mo semestre.")
                        results.append({
                            'Periodo_ID': p_id,
                            'Periodo_Nombre': period_name,
                            'Carrera_ID': carrera_id,
                            'Carrera_Nombre': carrera_name,
                            'Semestre': 10,
                            'Num_Estudiantes': num_students
                        })
                    except (IndexError, ValueError):
                        print(f"  Advertencia: No se pudo parsear la ID de carrera de {df_name}.")
            else:
                print(f"  No se encontraron DataFrames para el 10mo semestre en este período.")
        else:
            print(f"  Datos no disponibles para el período {period_name} (ID: {p_id}).")
            
    if not results:
        print("No se encontraron datos para el 10mo semestre en periodos 'B'.")
    else:
        tenth_sem_df = pd.DataFrame(results)
        print("\n--- Resumen General de Décimo Semestre ---")
        print(tenth_sem_df.pivot_table(index='Carrera_Nombre', columns='Periodo_Nombre', values='Num_Estudiantes', fill_value=0))
        return tenth_sem_df


def exploratory_population_analysis(data, p_map, p_type, c_names):
    """
    Realiza un análisis exploratorio general de la población por período, carrera y semestre.
    """
    print("\n" + "="*50)
    print("Análisis Exploratorio General de Población")
    print("="*50)

    all_students_data = []

    for p_id in period_order:
        period_key = f"p{p_id}"
        period_name = p_map.get(p_id, f"Periodo {p_id}")
        current_period_type = p_type.get(p_id, 'N/A')

        if period_key in data:
            period_dfs = data[period_key]
            for df_name, df in period_dfs.items():
                try:
                    # Parsear id_carrera y semestre del nombre del DataFrame
                    carrera_id = int(df_name.split('c')[1].split('s')[0])
                    semestre_id = int(df_name.split('s')[1])
                    carrera_name = c_names.get(carrera_id, f"Carrera {carrera_id}")
                    num_students = df['matricula_hash'].nunique()

                    all_students_data.append({
                        'Periodo_ID': p_id,
                        'Periodo_Nombre': period_name,
                        'Tipo_Periodo': current_period_type,
                        'Carrera_ID': carrera_id,
                        'Carrera_Nombre': carrera_name,
                        'Semestre': semestre_id,
                        'Num_Estudiantes': num_students
                    })
                except (IndexError, ValueError):
                    print(f"  Advertencia: No se pudo parsear la ID de carrera o semestre de {df_name}.")
        # else:
            # print(f"  Datos no disponibles para el período {period_name} (ID: {p_id}).") # Descomentar si quieres ver los periodos sin datos

    if not all_students_data:
        print("No se encontraron datos para el análisis exploratorio general.")
        return None

    full_df = pd.DataFrame(all_students_data)

    print("\n--- Total de Estudiantes por Periodo y Carrera ---")
    total_by_period_career = full_df.groupby(['Periodo_Nombre', 'Carrera_Nombre'])['Num_Estudiantes'].sum().unstack(fill_value=0)
    print(total_by_period_career)

    print("\n--- Estudiantes por Periodo, Carrera y Semestre (Primeros 5 registros) ---")
    print(full_df.head()) # Muestra los primeros registros del DataFrame completo

    print("\n--- Distribución de Estudiantes por Semestre (Promedio en todos los periodos) ---")
    avg_by_sem = full_df.groupby('Semestre')['Num_Estudiantes'].mean().sort_index()
    print(avg_by_sem)

    print("\n--- TOP 5 Carreras con más estudiantes (Promedio por periodo) ---")
    avg_by_career = full_df.groupby('Carrera_Nombre')['Num_Estudiantes'].sum().sort_values(ascending=False)
    print(avg_by_career.head())
    
    print("\n--- Estudiantes por Tipo de Periodo (A, B, V) ---")
    students_by_period_type = full_df.groupby('Tipo_Periodo')['Num_Estudiantes'].sum()
    print(students_by_period_type)

    return full_df

# --- Ejecutar los análisis ---
df_first_sem = analyze_first_sem_population(all_period_data, period_map, period_type, career_names)
print("\n" + "-"*80 + "\n") # Separador
df_tenth_sem = analyze_tenth_sem_population(all_period_data, period_map, period_type, career_names)
print("\n" + "-"*80 + "\n") # Separador
df_full_exploratory = exploratory_population_analysis(all_period_data, period_map, period_type, career_names)

print("\nAnálisis de población completado.")
# Out:
# Cargando datos desde: D:/TesisDB/CSV's
# Cargado: periodo35carrera10semestre1.csv en p35['p35c10s1']
# Cargado: periodo35carrera10semestre3.csv en p35['p35c10s3']
# Cargado: periodo35carrera10semestre5.csv en p35['p35c10s5']
# Cargado: periodo35carrera10semestre7.csv en p35['p35c10s7']
# Cargado: periodo35carrera10semestre9.csv en p35['p35c10s9']
# Cargado: periodo35carrera11semestre1.csv en p35['p35c11s1']
# Cargado: periodo35carrera11semestre3.csv en p35['p35c11s3']
# Cargado: periodo35carrera2semestre1.csv en p35['p35c2s1']
# Cargado: periodo35carrera2semestre3.csv en p35['p35c2s3']
# Cargado: periodo35carrera2semestre5.csv en p35['p35c2s5']
# Cargado: periodo35carrera2semestre7.csv en p35['p35c2s7']
# Cargado: periodo35carrera2semestre9.csv en p35['p35c2s9']
# Cargado: periodo35carrera3semestre1.csv en p35['p35c3s1']
# Cargado: periodo35carrera3semestre3.csv en p35['p35c3s3']
# Cargado: periodo35carrera3semestre5.csv en p35['p35c3s5']
# Cargado: periodo35carrera3semestre7.csv en p35['p35c3s7']
# Cargado: periodo35carrera3semestre9.csv en p35['p35c3s9']
# Cargado: periodo35carrera4semestre1.csv en p35['p35c4s1']
# Cargado: periodo35carrera4semestre3.csv en p35['p35c4s3']
# Cargado: periodo35carrera4semestre5.csv en p35['p35c4s5']
# Cargado: periodo35carrera4semestre7.csv en p35['p35c4s7']
# Cargado: periodo35carrera4semestre9.csv en p35['p35c4s9']
# Cargado: periodo35carrera5semestre1.csv en p35['p35c5s1']
# Cargado: periodo35carrera5semestre3.csv en p35['p35c5s3']
# Cargado: periodo35carrera5semestre5.csv en p35['p35c5s5']
# Cargado: periodo35carrera5semestre7.csv en p35['p35c5s7']
# Cargado: periodo35carrera5semestre9.csv en p35['p35c5s9']
# Cargado: periodo35carrera6semestre1.csv en p35['p35c6s1']
# Cargado: periodo35carrera6semestre3.csv en p35['p35c6s3']
# Cargado: periodo35carrera6semestre5.csv en p35['p35c6s5']
# Cargado: periodo35carrera6semestre7.csv en p35['p35c6s7']
# Cargado: periodo35carrera6semestre9.csv en p35['p35c6s9']
# Cargado: periodo35carrera7semestre1.csv en p35['p35c7s1']
# Cargado: periodo35carrera7semestre3.csv en p35['p35c7s3']
# Cargado: periodo35carrera7semestre5.csv en p35['p35c7s5']
# Cargado: periodo35carrera7semestre7.csv en p35['p35c7s7']
# Cargado: periodo35carrera7semestre9.csv en p35['p35c7s9']
# Cargado: periodo35carrera8semestre1.csv en p35['p35c8s1']
# Cargado: periodo35carrera8semestre3.csv en p35['p35c8s3']
# Cargado: periodo35carrera8semestre5.csv en p35['p35c8s5']
# Cargado: periodo35carrera8semestre7.csv en p35['p35c8s7']
# Cargado: periodo35carrera8semestre9.csv en p35['p35c8s9']
# Cargado: periodo35carrera9semestre1.csv en p35['p35c9s1']
# Cargado: periodo35carrera9semestre3.csv en p35['p35c9s3']
# Cargado: periodo35carrera9semestre5.csv en p35['p35c9s5']
# Cargado: periodo35carrera9semestre7.csv en p35['p35c9s7']
# Cargado: periodo35carrera9semestre9.csv en p35['p35c9s9']
# Cargado: periodo36carrera10semestre10.csv en p36['p36c10s10']
# Cargado: periodo36carrera10semestre2.csv en p36['p36c10s2']
# Cargado: periodo36carrera10semestre4.csv en p36['p36c10s4']
# Cargado: periodo36carrera10semestre6.csv en p36['p36c10s6']
# Cargado: periodo36carrera10semestre8.csv en p36['p36c10s8']
# Cargado: periodo36carrera11semestre2.csv en p36['p36c11s2']
# Cargado: periodo36carrera11semestre4.csv en p36['p36c11s4']
# Cargado: periodo36carrera2semestre10.csv en p36['p36c2s10']
# Cargado: periodo36carrera2semestre2.csv en p36['p36c2s2']
# Cargado: periodo36carrera2semestre4.csv en p36['p36c2s4']
# Cargado: periodo36carrera2semestre6.csv en p36['p36c2s6']
# Cargado: periodo36carrera2semestre8.csv en p36['p36c2s8']
# Cargado: periodo36carrera3semestre10.csv en p36['p36c3s10']
# Cargado: periodo36carrera3semestre2.csv en p36['p36c3s2']
# Cargado: periodo36carrera3semestre4.csv en p36['p36c3s4']
# Cargado: periodo36carrera3semestre6.csv en p36['p36c3s6']
# Cargado: periodo39carrera3semestre5.csv en p39['p39c3s5']
# Cargado: periodo39carrera3semestre7.csv en p39['p39c3s7']
# Cargado: periodo39carrera3semestre9.csv en p39['p39c3s9']
# Cargado: periodo39carrera4semestre1.csv en p39['p39c4s1']
# Cargado: periodo39carrera4semestre3.csv en p39['p39c4s3']
# Cargado: periodo39carrera4semestre5.csv en p39['p39c4s5']
# Cargado: periodo39carrera4semestre7.csv en p39['p39c4s7']
# Cargado: periodo39carrera4semestre9.csv en p39['p39c4s9']
# Cargado: periodo39carrera5semestre1.csv en p39['p39c5s1']
# Cargado: periodo39carrera5semestre3.csv en p39['p39c5s3']
# Cargado: periodo39carrera5semestre5.csv en p39['p39c5s5']
# Cargado: periodo39carrera5semestre7.csv en p39['p39c5s7']
# Cargado: periodo39carrera5semestre9.csv en p39['p39c5s9']
# Cargado: periodo39carrera6semestre1.csv en p39['p39c6s1']
# Cargado: periodo39carrera6semestre3.csv en p39['p39c6s3']
# Cargado: periodo39carrera6semestre5.csv en p39['p39c6s5']
# Cargado: periodo39carrera6semestre7.csv en p39['p39c6s7']
# Cargado: periodo39carrera6semestre9.csv en p39['p39c6s9']
# Cargado: periodo39carrera7semestre1.csv en p39['p39c7s1']
# Cargado: periodo39carrera7semestre3.csv en p39['p39c7s3']
# Cargado: periodo39carrera7semestre5.csv en p39['p39c7s5']
# Cargado: periodo39carrera7semestre7.csv en p39['p39c7s7']
# Cargado: periodo39carrera7semestre9.csv en p39['p39c7s9']
# Cargado: periodo39carrera8semestre1.csv en p39['p39c8s1']
# Cargado: periodo39carrera8semestre3.csv en p39['p39c8s3']
# Cargado: periodo39carrera8semestre5.csv en p39['p39c8s5']
# Cargado: periodo39carrera8semestre7.csv en p39['p39c8s7']
# Cargado: periodo39carrera8semestre9.csv en p39['p39c8s9']
# Cargado: periodo39carrera9semestre1.csv en p39['p39c9s1']
# Cargado: periodo39carrera9semestre3.csv en p39['p39c9s3']
# Cargado: periodo39carrera9semestre5.csv en p39['p39c9s5']
# Cargado: periodo39carrera9semestre7.csv en p39['p39c9s7']
# Cargado: periodo39carrera9semestre9.csv en p39['p39c9s9']
# Cargado: periodo40carrera10semestre1.csv en p40['p40c10s1']
# Cargado: periodo40carrera10semestre3.csv en p40['p40c10s3']
# Cargado: periodo40carrera10semestre5.csv en p40['p40c10s5']
# Cargado: periodo40carrera11semestre1.csv en p40['p40c11s1']
# Cargado: periodo40carrera11semestre3.csv en p40['p40c11s3']
# Cargado: periodo40carrera2semestre1.csv en p40['p40c2s1']
# Cargado: periodo40carrera2semestre2.csv en p40['p40c2s2']
# Cargado: periodo40carrera2semestre3.csv en p40['p40c2s3']
# Cargado: periodo40carrera2semestre7.csv en p40['p40c2s7']
# Cargado: periodo40carrera2semestre8.csv en p40['p40c2s8']
# Cargado: periodo40carrera3semestre1.csv en p40['p40c3s1']
# Cargado: periodo40carrera3semestre10.csv en p40['p40c3s10']
# Cargado: periodo40carrera3semestre3.csv en p40['p40c3s3']
# Cargado: periodo40carrera3semestre5.csv en p40['p40c3s5']
# Cargado: periodo40carrera3semestre7.csv en p40['p40c3s7']
# Cargado: periodo40carrera4semestre1.csv en p40['p40c4s1']
# Cargado: periodo40carrera4semestre3.csv en p40['p40c4s3']
# Cargado: periodo40carrera4semestre5.csv en p40['p40c4s5']
# Cargado: periodo40carrera4semestre7.csv en p40['p40c4s7']
# Cargado: periodo40carrera5semestre1.csv en p40['p40c5s1']
# Cargado: periodo40carrera5semestre3.csv en p40['p40c5s3']
# Cargado: periodo40carrera5semestre5.csv en p40['p40c5s5']
# Cargado: periodo40carrera5semestre8.csv en p40['p40c5s8']
# Cargado: periodo40carrera5semestre9.csv en p40['p40c5s9']
# Cargado: periodo40carrera6semestre1.csv en p40['p40c6s1']
# Cargado: periodo40carrera6semestre3.csv en p40['p40c6s3']
# Cargado: periodo40carrera7semestre1.csv en p40['p40c7s1']
# Cargado: periodo40carrera7semestre5.csv en p40['p40c7s5']
# Cargado: periodo40carrera7semestre7.csv en p40['p40c7s7']
# Cargado: periodo40carrera8semestre1.csv en p40['p40c8s1']
# Cargado: periodo40carrera8semestre3.csv en p40['p40c8s3']
# Cargado: periodo40carrera8semestre4.csv en p40['p40c8s4']
# Cargado: periodo40carrera8semestre7.csv en p40['p40c8s7']
# Cargado: periodo40carrera8semestre8.csv en p40['p40c8s8']
# Cargado: periodo40carrera8semestre9.csv en p40['p40c8s9']
# Cargado: periodo40carrera9semestre1.csv en p40['p40c9s1']
# Cargado: periodo40carrera9semestre2.csv en p40['p40c9s2']
# Cargado: periodo40carrera9semestre3.csv en p40['p40c9s3']
# Cargado: periodo40carrera9semestre5.csv en p40['p40c9s5']
# Cargado: periodo40carrera9semestre6.csv en p40['p40c9s6']
# Cargado: periodo40carrera9semestre7.csv en p40['p40c9s7']
# Cargado: periodo41carrera10semestre1.csv en p41['p41c10s1']
# Cargado: periodo41carrera10semestre3.csv en p41['p41c10s3']
# Cargado: periodo41carrera10semestre5.csv en p41['p41c10s5']
# Cargado: periodo41carrera10semestre7.csv en p41['p41c10s7']
# Cargado: periodo41carrera10semestre9.csv en p41['p41c10s9']
# Cargado: periodo41carrera11semestre1.csv en p41['p41c11s1']
# Cargado: periodo41carrera11semestre3.csv en p41['p41c11s3']
# Cargado: periodo41carrera11semestre5.csv en p41['p41c11s5']
# Cargado: periodo41carrera11semestre7.csv en p41['p41c11s7']
# Cargado: periodo41carrera2semestre1.csv en p41['p41c2s1']
# Cargado: periodo41carrera2semestre3.csv en p41['p41c2s3']
# Cargado: periodo41carrera2semestre5.csv en p41['p41c2s5']
# Cargado: periodo41carrera2semestre7.csv en p41['p41c2s7']
# Cargado: periodo41carrera2semestre9.csv en p41['p41c2s9']
# Cargado: periodo41carrera3semestre1.csv en p41['p41c3s1']
# Cargado: periodo41carrera3semestre3.csv en p41['p41c3s3']
# Cargado: periodo41carrera3semestre5.csv en p41['p41c3s5']
# Cargado: periodo41carrera3semestre7.csv en p41['p41c3s7']
# Cargado: periodo41carrera3semestre9.csv en p41['p41c3s9']
# Cargado: periodo41carrera4semestre1.csv en p41['p41c4s1']
# Cargado: periodo41carrera4semestre3.csv en p41['p41c4s3']
# Cargado: periodo41carrera4semestre5.csv en p41['p41c4s5']
# Cargado: periodo41carrera4semestre7.csv en p41['p41c4s7']
# Cargado: periodo41carrera4semestre9.csv en p41['p41c4s9']
# Cargado: periodo41carrera5semestre1.csv en p41['p41c5s1']
# Cargado: periodo41carrera5semestre3.csv en p41['p41c5s3']
# Cargado: periodo41carrera5semestre5.csv en p41['p41c5s5']
# Cargado: periodo41carrera5semestre7.csv en p41['p41c5s7']
# Cargado: periodo41carrera5semestre9.csv en p41['p41c5s9']
# Cargado: periodo41carrera6semestre1.csv en p41['p41c6s1']
# Cargado: periodo41carrera6semestre3.csv en p41['p41c6s3']
# Cargado: periodo41carrera6semestre5.csv en p41['p41c6s5']
# Cargado: periodo41carrera6semestre7.csv en p41['p41c6s7']
# Cargado: periodo41carrera6semestre9.csv en p41['p41c6s9']
# Cargado: periodo41carrera7semestre1.csv en p41['p41c7s1']
# Cargado: periodo41carrera7semestre3.csv en p41['p41c7s3']
# Cargado: periodo41carrera7semestre5.csv en p41['p41c7s5']
# Cargado: periodo41carrera7semestre7.csv en p41['p41c7s7']
# Cargado: periodo41carrera7semestre9.csv en p41['p41c7s9']
# Cargado: periodo41carrera8semestre1.csv en p41['p41c8s1']
# Cargado: periodo41carrera8semestre3.csv en p41['p41c8s3']
# Cargado: periodo41carrera8semestre5.csv en p41['p41c8s5']
# Cargado: periodo41carrera8semestre7.csv en p41['p41c8s7']
# Cargado: periodo41carrera8semestre9.csv en p41['p41c8s9']
# Cargado: periodo41carrera9semestre1.csv en p41['p41c9s1']
# Cargado: periodo41carrera9semestre3.csv en p41['p41c9s3']
# Cargado: periodo41carrera9semestre5.csv en p41['p41c9s5']
# Cargado: periodo41carrera9semestre7.csv en p41['p41c9s7']
# Cargado: periodo41carrera9semestre9.csv en p41['p41c9s9']
# Cargado: periodo42carrera10semestre10.csv en p42['p42c10s10']
# Cargado: periodo42carrera10semestre2.csv en p42['p42c10s2']
# Cargado: periodo42carrera10semestre4.csv en p42['p42c10s4']
# Cargado: periodo42carrera10semestre6.csv en p42['p42c10s6']
# Cargado: periodo42carrera10semestre8.csv en p42['p42c10s8']
# Cargado: periodo42carrera11semestre2.csv en p42['p42c11s2']
# Cargado: periodo42carrera11semestre4.csv en p42['p42c11s4']
# Cargado: periodo42carrera11semestre6.csv en p42['p42c11s6']
# Cargado: periodo42carrera2semestre10.csv en p42['p42c2s10']
# Cargado: periodo42carrera2semestre2.csv en p42['p42c2s2']
# Cargado: periodo42carrera2semestre4.csv en p42['p42c2s4']
# Cargado: periodo42carrera2semestre6.csv en p42['p42c2s6']
# Cargado: periodo42carrera2semestre8.csv en p42['p42c2s8']
# Cargado: periodo42carrera3semestre10.csv en p42['p42c3s10']
# Cargado: periodo42carrera3semestre2.csv en p42['p42c3s2']
# Cargado: periodo42carrera3semestre4.csv en p42['p42c3s4']
# Cargado: periodo42carrera3semestre6.csv en p42['p42c3s6']
# Cargado: periodo42carrera3semestre8.csv en p42['p42c3s8']
# Cargado: periodo42carrera4semestre10.csv en p42['p42c4s10']
# Cargado: periodo42carrera4semestre2.csv en p42['p42c4s2']
# Cargado: periodo42carrera4semestre4.csv en p42['p42c4s4']
# Cargado: periodo42carrera4semestre6.csv en p42['p42c4s6']
# Cargado: periodo42carrera4semestre8.csv en p42['p42c4s8']
# Cargado: periodo42carrera5semestre10.csv en p42['p42c5s10']
# Cargado: periodo42carrera5semestre2.csv en p42['p42c5s2']
# Cargado: periodo42carrera5semestre4.csv en p42['p42c5s4']
# Cargado: periodo42carrera5semestre6.csv en p42['p42c5s6']
# Cargado: periodo42carrera5semestre8.csv en p42['p42c5s8']
# Cargado: periodo42carrera6semestre10.csv en p42['p42c6s10']
# Cargado: periodo42carrera6semestre2.csv en p42['p42c6s2']
# Cargado: periodo42carrera6semestre4.csv en p42['p42c6s4']
# Cargado: periodo42carrera6semestre6.csv en p42['p42c6s6']
# Cargado: periodo42carrera6semestre8.csv en p42['p42c6s8']
# Cargado: periodo42carrera7semestre10.csv en p42['p42c7s10']
# Cargado: periodo42carrera7semestre2.csv en p42['p42c7s2']
# Cargado: periodo42carrera7semestre4.csv en p42['p42c7s4']
# Cargado: periodo42carrera7semestre6.csv en p42['p42c7s6']
# Cargado: periodo42carrera7semestre8.csv en p42['p42c7s8']
# Cargado: periodo42carrera8semestre10.csv en p42['p42c8s10']
# Cargado: periodo42carrera8semestre2.csv en p42['p42c8s2']
# Cargado: periodo42carrera8semestre4.csv en p42['p42c8s4']
# Cargado: periodo42carrera8semestre6.csv en p42['p42c8s6']
# Cargado: periodo42carrera8semestre8.csv en p42['p42c8s8']
# Cargado: periodo42carrera9semestre10.csv en p42['p42c9s10']
# Cargado: periodo42carrera9semestre2.csv en p42['p42c9s2']
# Cargado: periodo42carrera9semestre4.csv en p42['p42c9s4']
# Cargado: periodo42carrera9semestre6.csv en p42['p42c9s6']
# Cargado: periodo42carrera9semestre8.csv en p42['p42c9s8']
# Cargado: periodo43carrera10semestre1.csv en p43['p43c10s1']
# Cargado: periodo43carrera10semestre5.csv en p43['p43c10s5']
# Cargado: periodo43carrera10semestre6.csv en p43['p43c10s6']
# Cargado: periodo43carrera10semestre7.csv en p43['p43c10s7']
# Cargado: periodo43carrera11semestre1.csv en p43['p43c11s1']
# Cargado: periodo43carrera11semestre2.csv en p43['p43c11s2']
# Cargado: periodo43carrera11semestre3.csv en p43['p43c11s3']
# Cargado: periodo43carrera11semestre5.csv en p43['p43c11s5']
# Cargado: periodo43carrera2semestre1.csv en p43['p43c2s1']
# Cargado: periodo43carrera2semestre3.csv en p43['p43c2s3']
# Cargado: periodo43carrera2semestre5.csv en p43['p43c2s5']
# Cargado: periodo43carrera2semestre7.csv en p43['p43c2s7']
# Cargado: periodo44carrera2semestre9.csv en p44['p44c2s9']
# Cargado: periodo44carrera3semestre1.csv en p44['p44c3s1']
# Cargado: periodo44carrera3semestre3.csv en p44['p44c3s3']
# Cargado: periodo44carrera3semestre5.csv en p44['p44c3s5']
# Cargado: periodo44carrera3semestre7.csv en p44['p44c3s7']
# Cargado: periodo44carrera3semestre9.csv en p44['p44c3s9']
# Cargado: periodo44carrera4semestre1.csv en p44['p44c4s1']
# Cargado: periodo44carrera4semestre3.csv en p44['p44c4s3']
# Cargado: periodo44carrera4semestre5.csv en p44['p44c4s5']
# Cargado: periodo44carrera4semestre7.csv en p44['p44c4s7']
# Cargado: periodo44carrera4semestre9.csv en p44['p44c4s9']
# Cargado: periodo44carrera5semestre1.csv en p44['p44c5s1']
# Cargado: periodo44carrera5semestre3.csv en p44['p44c5s3']
# Cargado: periodo44carrera5semestre5.csv en p44['p44c5s5']
# Cargado: periodo44carrera5semestre7.csv en p44['p44c5s7']
# Cargado: periodo44carrera5semestre9.csv en p44['p44c5s9']
# Cargado: periodo44carrera6semestre1.csv en p44['p44c6s1']
# Cargado: periodo44carrera6semestre3.csv en p44['p44c6s3']
# Cargado: periodo44carrera6semestre5.csv en p44['p44c6s5']
# Cargado: periodo44carrera6semestre7.csv en p44['p44c6s7']
# Cargado: periodo44carrera6semestre9.csv en p44['p44c6s9']
# Cargado: periodo44carrera7semestre1.csv en p44['p44c7s1']
# Cargado: periodo44carrera7semestre3.csv en p44['p44c7s3']
# Cargado: periodo44carrera7semestre5.csv en p44['p44c7s5']
# Cargado: periodo44carrera7semestre7.csv en p44['p44c7s7']
# Cargado: periodo44carrera7semestre9.csv en p44['p44c7s9']
# Cargado: periodo44carrera8semestre1.csv en p44['p44c8s1']
# Cargado: periodo44carrera8semestre3.csv en p44['p44c8s3']
# Cargado: periodo44carrera8semestre5.csv en p44['p44c8s5']
# Cargado: periodo44carrera8semestre7.csv en p44['p44c8s7']
# Cargado: periodo44carrera8semestre9.csv en p44['p44c8s9']
# Cargado: periodo44carrera9semestre1.csv en p44['p44c9s1']
# Cargado: periodo44carrera9semestre3.csv en p44['p44c9s3']
# Cargado: periodo44carrera9semestre5.csv en p44['p44c9s5']
# Cargado: periodo44carrera9semestre7.csv en p44['p44c9s7']
# Cargado: periodo44carrera9semestre9.csv en p44['p44c9s9']
# Cargado: periodo46carrera10semestre10.csv en p46['p46c10s10']
# Cargado: periodo46carrera10semestre2.csv en p46['p46c10s2']
# Cargado: periodo46carrera10semestre4.csv en p46['p46c10s4']
# Cargado: periodo46carrera10semestre6.csv en p46['p46c10s6']
# Cargado: periodo46carrera10semestre8.csv en p46['p46c10s8']
# Cargado: periodo46carrera11semestre2.csv en p46['p46c11s2']
# Cargado: periodo46carrera11semestre4.csv en p46['p46c11s4']
# Cargado: periodo46carrera11semestre6.csv en p46['p46c11s6']
# Cargado: periodo46carrera11semestre8.csv en p46['p46c11s8']
# Cargado: periodo46carrera2semestre10.csv en p46['p46c2s10']
# Cargado: periodo46carrera2semestre2.csv en p46['p46c2s2']
# Cargado: periodo46carrera2semestre4.csv en p46['p46c2s4']
# Cargado: periodo46carrera2semestre6.csv en p46['p46c2s6']
# Cargado: periodo46carrera2semestre8.csv en p46['p46c2s8']
# Cargado: periodo46carrera3semestre10.csv en p46['p46c3s10']
# Cargado: periodo46carrera3semestre2.csv en p46['p46c3s2']
# Cargado: periodo46carrera3semestre4.csv en p46['p46c3s4']
# Cargado: periodo46carrera3semestre6.csv en p46['p46c3s6']
# Cargado: periodo46carrera3semestre8.csv en p46['p46c3s8']
# Cargado: periodo46carrera4semestre10.csv en p46['p46c4s10']
# Cargado: periodo46carrera4semestre2.csv en p46['p46c4s2']
# Cargado: periodo46carrera4semestre4.csv en p46['p46c4s4']
# Cargado: periodo46carrera4semestre6.csv en p46['p46c4s6']
# Cargado: periodo46carrera4semestre8.csv en p46['p46c4s8']
# Cargado: periodo46carrera5semestre10.csv en p46['p46c5s10']
# Cargado: periodo46carrera5semestre2.csv en p46['p46c5s2']
# Cargado: periodo46carrera5semestre4.csv en p46['p46c5s4']
# Cargado: periodo46carrera5semestre6.csv en p46['p46c5s6']
# Cargado: periodo46carrera5semestre8.csv en p46['p46c5s8']
# Cargado: periodo46carrera6semestre10.csv en p46['p46c6s10']
# Cargado: periodo46carrera6semestre2.csv en p46['p46c6s2']
# Cargado: periodo46carrera6semestre4.csv en p46['p46c6s4']
# Cargado: periodo46carrera6semestre6.csv en p46['p46c6s6']
# Cargado: periodo46carrera6semestre8.csv en p46['p46c6s8']
# Cargado: periodo46carrera7semestre10.csv en p46['p46c7s10']
# Cargado: periodo46carrera7semestre2.csv en p46['p46c7s2']
# Cargado: periodo46carrera7semestre4.csv en p46['p46c7s4']
# Cargado: periodo46carrera7semestre6.csv en p46['p46c7s6']
# Cargado: periodo46carrera7semestre8.csv en p46['p46c7s8']
# Cargado: periodo46carrera8semestre10.csv en p46['p46c8s10']
# Cargado: periodo46carrera8semestre2.csv en p46['p46c8s2']
# Cargado: periodo46carrera8semestre4.csv en p46['p46c8s4']
# Cargado: periodo46carrera8semestre6.csv en p46['p46c8s6']
# Cargado: periodo46carrera8semestre8.csv en p46['p46c8s8']
# Cargado: periodo46carrera9semestre10.csv en p46['p46c9s10']
# Cargado: periodo46carrera9semestre2.csv en p46['p46c9s2']
# Cargado: periodo46carrera9semestre4.csv en p46['p46c9s4']
# Cargado: periodo46carrera9semestre6.csv en p46['p46c9s6']
# Cargado: periodo46carrera9semestre8.csv en p46['p46c9s8']
# Cargado: periodo47carrera10semestre1.csv en p47['p47c10s1']
# Cargado: periodo47carrera10semestre2.csv en p47['p47c10s2']
# Cargado: periodo47carrera10semestre3.csv en p47['p47c10s3']
# Cargado: periodo47carrera10semestre4.csv en p47['p47c10s4']
# Cargado: periodo47carrera10semestre7.csv en p47['p47c10s7']
# Cargado: periodo47carrera11semestre1.csv en p47['p47c11s1']
# Cargado: periodo47carrera11semestre2.csv en p47['p47c11s2']
# Cargado: periodo48carrera2semestre1.csv en p48['p48c2s1']
# Cargado: periodo48carrera2semestre3.csv en p48['p48c2s3']
# Cargado: periodo48carrera2semestre5.csv en p48['p48c2s5']
# Cargado: periodo48carrera2semestre7.csv en p48['p48c2s7']
# Cargado: periodo48carrera2semestre9.csv en p48['p48c2s9']
# Cargado: periodo48carrera3semestre1.csv en p48['p48c3s1']
# Cargado: periodo48carrera3semestre3.csv en p48['p48c3s3']
# Cargado: periodo48carrera3semestre5.csv en p48['p48c3s5']
# Cargado: periodo48carrera3semestre7.csv en p48['p48c3s7']
# Cargado: periodo48carrera3semestre9.csv en p48['p48c3s9']
# Cargado: periodo48carrera4semestre1.csv en p48['p48c4s1']
# Cargado: periodo48carrera4semestre3.csv en p48['p48c4s3']
# Cargado: periodo48carrera4semestre5.csv en p48['p48c4s5']
# Cargado: periodo48carrera4semestre7.csv en p48['p48c4s7']
# Cargado: periodo48carrera4semestre9.csv en p48['p48c4s9']
# Cargado: periodo48carrera5semestre1.csv en p48['p48c5s1']
# Cargado: periodo48carrera5semestre3.csv en p48['p48c5s3']
# Cargado: periodo48carrera5semestre5.csv en p48['p48c5s5']
# Cargado: periodo48carrera5semestre7.csv en p48['p48c5s7']
# Cargado: periodo48carrera5semestre9.csv en p48['p48c5s9']
# Cargado: periodo48carrera6semestre1.csv en p48['p48c6s1']
# Cargado: periodo48carrera6semestre3.csv en p48['p48c6s3']
# Cargado: periodo48carrera6semestre5.csv en p48['p48c6s5']
# Cargado: periodo48carrera6semestre7.csv en p48['p48c6s7']
# Cargado: periodo48carrera6semestre9.csv en p48['p48c6s9']
# Cargado: periodo48carrera7semestre1.csv en p48['p48c7s1']
# Cargado: periodo48carrera7semestre3.csv en p48['p48c7s3']
# Cargado: periodo48carrera7semestre5.csv en p48['p48c7s5']
# Cargado: periodo48carrera7semestre7.csv en p48['p48c7s7']
# Cargado: periodo48carrera7semestre9.csv en p48['p48c7s9']
# Cargado: periodo48carrera8semestre1.csv en p48['p48c8s1']
# Cargado: periodo48carrera8semestre3.csv en p48['p48c8s3']
# Cargado: periodo48carrera8semestre5.csv en p48['p48c8s5']
# Cargado: periodo48carrera8semestre7.csv en p48['p48c8s7']
# Cargado: periodo48carrera8semestre9.csv en p48['p48c8s9']
# Cargado: periodo48carrera9semestre1.csv en p48['p48c9s1']
# Cargado: periodo48carrera9semestre3.csv en p48['p48c9s3']
# Cargado: periodo48carrera9semestre5.csv en p48['p48c9s5']
# Cargado: periodo48carrera9semestre7.csv en p48['p48c9s7']
# Cargado: periodo48carrera9semestre9.csv en p48['p48c9s9']
# Cargado: periodo49carrera10semestre10.csv en p49['p49c10s10']
# Cargado: periodo49carrera10semestre2.csv en p49['p49c10s2']
# Cargado: periodo49carrera10semestre4.csv en p49['p49c10s4']
# Cargado: periodo49carrera10semestre6.csv en p49['p49c10s6']
# Cargado: periodo49carrera10semestre8.csv en p49['p49c10s8']
# Cargado: periodo49carrera11semestre10.csv en p49['p49c11s10']
# Cargado: periodo49carrera11semestre2.csv en p49['p49c11s2']
# Cargado: periodo49carrera11semestre4.csv en p49['p49c11s4']
# Cargado: periodo49carrera11semestre6.csv en p49['p49c11s6']
# Cargado: periodo49carrera11semestre8.csv en p49['p49c11s8']
# Cargado: periodo49carrera12semestre2.csv en p49['p49c12s2']
# Cargado: periodo49carrera2semestre10.csv en p49['p49c2s10']
# Cargado: periodo49carrera2semestre2.csv en p49['p49c2s2']
# Cargado: periodo49carrera2semestre4.csv en p49['p49c2s4']
# Cargado: periodo49carrera2semestre6.csv en p49['p49c2s6']
# Cargado: periodo49carrera2semestre8.csv en p49['p49c2s8']
# Cargado: periodo49carrera3semestre10.csv en p49['p49c3s10']
# Cargado: periodo49carrera3semestre2.csv en p49['p49c3s2']
# Cargado: periodo49carrera3semestre4.csv en p49['p49c3s4']
# Cargado: periodo49carrera3semestre6.csv en p49['p49c3s6']
# Cargado: periodo49carrera3semestre8.csv en p49['p49c3s8']
# Cargado: periodo49carrera4semestre10.csv en p49['p49c4s10']
# Cargado: periodo49carrera4semestre2.csv en p49['p49c4s2']
# Cargado: periodo49carrera4semestre4.csv en p49['p49c4s4']
# Cargado: periodo49carrera4semestre6.csv en p49['p49c4s6']
# Cargado: periodo49carrera4semestre8.csv en p49['p49c4s8']
# Cargado: periodo49carrera5semestre10.csv en p49['p49c5s10']
# Cargado: periodo49carrera5semestre2.csv en p49['p49c5s2']
# Cargado: periodo49carrera5semestre4.csv en p49['p49c5s4']
# Cargado: periodo49carrera5semestre6.csv en p49['p49c5s6']
# Cargado: periodo49carrera5semestre8.csv en p49['p49c5s8']
# Cargado: periodo49carrera6semestre10.csv en p49['p49c6s10']
# Cargado: periodo49carrera6semestre2.csv en p49['p49c6s2']
# Cargado: periodo49carrera6semestre4.csv en p49['p49c6s4']
# Cargado: periodo49carrera6semestre6.csv en p49['p49c6s6']
# Cargado: periodo49carrera6semestre8.csv en p49['p49c6s8']
# Cargado: periodo49carrera7semestre10.csv en p49['p49c7s10']
# Cargado: periodo49carrera7semestre2.csv en p49['p49c7s2']
# Cargado: periodo49carrera7semestre4.csv en p49['p49c7s4']
# Cargado: periodo49carrera7semestre6.csv en p49['p49c7s6']
# Cargado: periodo49carrera7semestre8.csv en p49['p49c7s8']
# Cargado: periodo49carrera8semestre10.csv en p49['p49c8s10']
# Cargado: periodo49carrera8semestre2.csv en p49['p49c8s2']
# Cargado: periodo49carrera8semestre4.csv en p49['p49c8s4']
# Cargado: periodo49carrera8semestre6.csv en p49['p49c8s6']
# Cargado: periodo49carrera8semestre8.csv en p49['p49c8s8']
# Cargado: periodo49carrera9semestre10.csv en p49['p49c9s10']
# Cargado: periodo49carrera9semestre2.csv en p49['p49c9s2']
# Cargado: periodo49carrera9semestre4.csv en p49['p49c9s4']
# Cargado: periodo49carrera9semestre6.csv en p49['p49c9s6']
# Cargado: periodo49carrera9semestre8.csv en p49['p49c9s8']
# Cargado: periodo50carrera10semestre3.csv en p50['p50c10s3']
# Cargado: periodo51carrera2semestre9.csv en p51['p51c2s9']
# Cargado: periodo51carrera3semestre1.csv en p51['p51c3s1']
# Cargado: periodo51carrera3semestre3.csv en p51['p51c3s3']
# Cargado: periodo51carrera3semestre5.csv en p51['p51c3s5']
# Cargado: periodo51carrera3semestre7.csv en p51['p51c3s7']
# Cargado: periodo51carrera3semestre9.csv en p51['p51c3s9']
# Cargado: periodo51carrera4semestre1.csv en p51['p51c4s1']
# Cargado: periodo51carrera4semestre3.csv en p51['p51c4s3']
# Cargado: periodo51carrera4semestre5.csv en p51['p51c4s5']
# Cargado: periodo51carrera4semestre7.csv en p51['p51c4s7']
# Cargado: periodo51carrera4semestre9.csv en p51['p51c4s9']
# Cargado: periodo51carrera5semestre1.csv en p51['p51c5s1']
# Cargado: periodo51carrera5semestre3.csv en p51['p51c5s3']
# Cargado: periodo51carrera5semestre5.csv en p51['p51c5s5']
# Cargado: periodo51carrera5semestre7.csv en p51['p51c5s7']
# Cargado: periodo51carrera5semestre9.csv en p51['p51c5s9']
# Cargado: periodo51carrera6semestre1.csv en p51['p51c6s1']
# Cargado: periodo51carrera6semestre3.csv en p51['p51c6s3']
# Cargado: periodo51carrera6semestre5.csv en p51['p51c6s5']
# Cargado: periodo51carrera6semestre7.csv en p51['p51c6s7']
# Cargado: periodo51carrera6semestre9.csv en p51['p51c6s9']
# Cargado: periodo51carrera7semestre1.csv en p51['p51c7s1']
# Cargado: periodo51carrera7semestre3.csv en p51['p51c7s3']
# Cargado: periodo51carrera7semestre5.csv en p51['p51c7s5']
# Cargado: periodo51carrera7semestre7.csv en p51['p51c7s7']
# Cargado: periodo51carrera7semestre9.csv en p51['p51c7s9']
# Cargado: periodo51carrera8semestre1.csv en p51['p51c8s1']
# Cargado: periodo51carrera8semestre3.csv en p51['p51c8s3']
# Cargado: periodo51carrera8semestre5.csv en p51['p51c8s5']
# Cargado: periodo51carrera8semestre7.csv en p51['p51c8s7']
# Cargado: periodo51carrera8semestre9.csv en p51['p51c8s9']
# Cargado: periodo51carrera9semestre1.csv en p51['p51c9s1']
# Cargado: periodo51carrera9semestre3.csv en p51['p51c9s3']
# Cargado: periodo51carrera9semestre5.csv en p51['p51c9s5']
# Cargado: periodo51carrera9semestre7.csv en p51['p51c9s7']
# Cargado: periodo51carrera9semestre9.csv en p51['p51c9s9']
# Cargado: periodo52carrera10semestre10.csv en p52['p52c10s10']
# Cargado: periodo52carrera10semestre2.csv en p52['p52c10s2']
# Cargado: periodo52carrera10semestre4.csv en p52['p52c10s4']
# Cargado: periodo52carrera10semestre6.csv en p52['p52c10s6']
# Cargado: periodo52carrera10semestre8.csv en p52['p52c10s8']
# Cargado: periodo52carrera11semestre10.csv en p52['p52c11s10']
# Cargado: periodo52carrera11semestre2.csv en p52['p52c11s2']
# Cargado: periodo52carrera11semestre4.csv en p52['p52c11s4']
# Cargado: periodo52carrera11semestre6.csv en p52['p52c11s6']
# Cargado: periodo52carrera11semestre8.csv en p52['p52c11s8']
# Cargado: periodo52carrera12semestre2.csv en p52['p52c12s2']
# Cargado: periodo52carrera12semestre4.csv en p52['p52c12s4']
# Cargado: periodo52carrera12semestre6.csv en p52['p52c12s6']
# Cargado: periodo52carrera2semestre10.csv en p52['p52c2s10']
# Cargado: periodo52carrera2semestre2.csv en p52['p52c2s2']
# Cargado: periodo52carrera2semestre4.csv en p52['p52c2s4']
# Cargado: periodo52carrera2semestre6.csv en p52['p52c2s6']
# Cargado: periodo52carrera2semestre8.csv en p52['p52c2s8']
# Cargado: periodo52carrera3semestre10.csv en p52['p52c3s10']
# Cargado: periodo52carrera3semestre2.csv en p52['p52c3s2']
# Cargado: periodo52carrera3semestre4.csv en p52['p52c3s4']
# Cargado: periodo52carrera3semestre6.csv en p52['p52c3s6']
# Cargado: periodo52carrera3semestre8.csv en p52['p52c3s8']
# Cargado: periodo52carrera4semestre10.csv en p52['p52c4s10']
# Cargado: periodo52carrera4semestre2.csv en p52['p52c4s2']
# Cargado: periodo52carrera4semestre4.csv en p52['p52c4s4']
# Cargado: periodo52carrera4semestre6.csv en p52['p52c4s6']
# Cargado: periodo52carrera4semestre8.csv en p52['p52c4s8']
# Cargado: periodo52carrera5semestre10.csv en p52['p52c5s10']
# Cargado: periodo52carrera5semestre2.csv en p52['p52c5s2']
# Cargado: periodo52carrera5semestre4.csv en p52['p52c5s4']
# Cargado: periodo52carrera5semestre6.csv en p52['p52c5s6']
# Cargado: periodo52carrera5semestre8.csv en p52['p52c5s8']
# Cargado: periodo52carrera6semestre10.csv en p52['p52c6s10']
# Cargado: periodo52carrera6semestre2.csv en p52['p52c6s2']
# Cargado: periodo52carrera6semestre4.csv en p52['p52c6s4']
# Cargado: periodo52carrera6semestre6.csv en p52['p52c6s6']
# Cargado: periodo52carrera6semestre8.csv en p52['p52c6s8']
# Cargado: periodo52carrera7semestre10.csv en p52['p52c7s10']
# Cargado: periodo52carrera7semestre2.csv en p52['p52c7s2']
# Cargado: periodo52carrera7semestre4.csv en p52['p52c7s4']
# Cargado: periodo52carrera7semestre6.csv en p52['p52c7s6']
# Cargado: periodo52carrera7semestre8.csv en p52['p52c7s8']
# Cargado: periodo52carrera8semestre10.csv en p52['p52c8s10']
# Cargado: periodo52carrera8semestre2.csv en p52['p52c8s2']
# Cargado: periodo52carrera8semestre4.csv en p52['p52c8s4']
# Cargado: periodo52carrera8semestre6.csv en p52['p52c8s6']
# Cargado: periodo52carrera8semestre8.csv en p52['p52c8s8']
# Cargado: periodo52carrera9semestre10.csv en p52['p52c9s10']
# Cargado: periodo52carrera9semestre2.csv en p52['p52c9s2']
# Cargado: periodo52carrera9semestre4.csv en p52['p52c9s4']
# Cargado: periodo52carrera9semestre6.csv en p52['p52c9s6']
# Cargado: periodo52carrera9semestre8.csv en p52['p52c9s8']
# Cargado: periodo53carrera10semestre10.csv en p53['p53c10s10']
# Cargado: periodo53carrera10semestre2.csv en p53['p53c10s2']
# Cargado: periodo53carrera10semestre4.csv en p53['p53c10s4']
# Cargado: periodo53carrera10semestre6.csv en p53['p53c10s6']
# Cargado: periodo53carrera10semestre8.csv en p53['p53c10s8']
# Cargado: periodo53carrera11semestre10.csv en p53['p53c11s10']
# Cargado: periodo53carrera11semestre2.csv en p53['p53c11s2']
# Cargado: periodo53carrera11semestre4.csv en p53['p53c11s4']
# Cargado: periodo53carrera11semestre6.csv en p53['p53c11s6']
# Cargado: periodo53carrera11semestre8.csv en p53['p53c11s8']
# Cargado: periodo53carrera12semestre2.csv en p53['p53c12s2']
# Cargado: periodo53carrera12semestre4.csv en p53['p53c12s4']
# Cargado: periodo53carrera2semestre10.csv en p53['p53c2s10']
# Cargado: periodo53carrera2semestre2.csv en p53['p53c2s2']
# Cargado: periodo53carrera2semestre4.csv en p53['p53c2s4']
# Cargado: periodo53carrera2semestre6.csv en p53['p53c2s6']
# Cargado: periodo53carrera2semestre8.csv en p53['p53c2s8']
# Cargado: periodo53carrera3semestre10.csv en p53['p53c3s10']
# Cargado: periodo53carrera3semestre2.csv en p53['p53c3s2']
# Cargado: periodo53carrera3semestre4.csv en p53['p53c3s4']
# Cargado: periodo53carrera3semestre6.csv en p53['p53c3s6']
# Cargado: periodo53carrera3semestre8.csv en p53['p53c3s8']
# Cargado: periodo53carrera4semestre10.csv en p53['p53c4s10']
# Cargado: periodo53carrera4semestre2.csv en p53['p53c4s2']
# Cargado: periodo53carrera4semestre4.csv en p53['p53c4s4']
# Cargado: periodo53carrera4semestre6.csv en p53['p53c4s6']
# Cargado: periodo53carrera4semestre8.csv en p53['p53c4s8']
# Cargado: periodo53carrera5semestre10.csv en p53['p53c5s10']
# Cargado: periodo53carrera5semestre2.csv en p53['p53c5s2']
# Cargado: periodo53carrera5semestre4.csv en p53['p53c5s4']
# Cargado: periodo53carrera5semestre6.csv en p53['p53c5s6']
# Cargado: periodo53carrera5semestre8.csv en p53['p53c5s8']
# Cargado: periodo53carrera6semestre10.csv en p53['p53c6s10']
# Cargado: periodo53carrera6semestre2.csv en p53['p53c6s2']
# Cargado: periodo53carrera6semestre4.csv en p53['p53c6s4']
# Cargado: periodo53carrera6semestre6.csv en p53['p53c6s6']
# Cargado: periodo53carrera6semestre8.csv en p53['p53c6s8']
# Cargado: periodo53carrera7semestre10.csv en p53['p53c7s10']
# Cargado: periodo53carrera7semestre2.csv en p53['p53c7s2']
# Cargado: periodo53carrera7semestre4.csv en p53['p53c7s4']
# Cargado: periodo53carrera7semestre6.csv en p53['p53c7s6']
# Cargado: periodo53carrera7semestre8.csv en p53['p53c7s8']
# Cargado: periodo53carrera8semestre10.csv en p53['p53c8s10']
# Cargado: periodo53carrera8semestre2.csv en p53['p53c8s2']
# Cargado: periodo53carrera8semestre4.csv en p53['p53c8s4']
# Cargado: periodo53carrera8semestre6.csv en p53['p53c8s6']
# Cargado: periodo53carrera8semestre8.csv en p53['p53c8s8']
# Cargado: periodo53carrera9semestre10.csv en p53['p53c9s10']
# Cargado: periodo53carrera9semestre2.csv en p53['p53c9s2']
# Cargado: periodo53carrera9semestre4.csv en p53['p53c9s4']
# Cargado: periodo53carrera9semestre6.csv en p53['p53c9s6']
# Cargado: periodo53carrera9semestre8.csv en p53['p53c9s8']
# Cargado: periodo54carrera10semestre1.csv en p54['p54c10s1']
# Cargado: periodo54carrera10semestre3.csv en p54['p54c10s3']
# Cargado: periodo54carrera10semestre5.csv en p54['p54c10s5']
# Cargado: periodo54carrera11semestre1.csv en p54['p54c11s1']
# Cargado: periodo54carrera11semestre3.csv en p54['p54c11s3']
# Cargado: periodo54carrera11semestre5.csv en p54['p54c11s5']
# Cargado: periodo54carrera11semestre6.csv en p54['p54c11s6']
# Cargado: periodo54carrera11semestre7.csv en p54['p54c11s7']
# Cargado: periodo54carrera12semestre1.csv en p54['p54c12s1']
# Cargado: periodo54carrera12semestre3.csv en p54['p54c12s3']
# Cargado: periodo54carrera2semestre1.csv en p54['p54c2s1']
# Cargado: periodo54carrera2semestre3.csv en p54['p54c2s3']
# Cargado: periodo54carrera2semestre4.csv en p54['p54c2s4']
# Cargado: periodo54carrera2semestre5.csv en p54['p54c2s5']
# Cargado: periodo54carrera2semestre9.csv en p54['p54c2s9']
# Cargado: periodo54carrera3semestre1.csv en p54['p54c3s1']
# Cargado: periodo54carrera3semestre3.csv en p54['p54c3s3']
# Cargado: periodo54carrera3semestre5.csv en p54['p54c3s5']
# Cargado: periodo54carrera3semestre9.csv en p54['p54c3s9']
# Cargado: periodo54carrera4semestre1.csv en p54['p54c4s1']
# Cargado: periodo54carrera4semestre3.csv en p54['p54c4s3']
# Cargado: periodo54carrera4semestre7.csv en p54['p54c4s7']
# Cargado: periodo54carrera5semestre1.csv en p54['p54c5s1']
# Cargado: periodo54carrera5semestre3.csv en p54['p54c5s3']
# Cargado: periodo54carrera5semestre5.csv en p54['p54c5s5']
# Cargado: periodo54carrera6semestre1.csv en p54['p54c6s1']
# Cargado: periodo54carrera6semestre3.csv en p54['p54c6s3']
# Cargado: periodo54carrera6semestre5.csv en p54['p54c6s5']
# Cargado: periodo54carrera7semestre1.csv en p54['p54c7s1']
# Cargado: periodo54carrera8semestre1.csv en p54['p54c8s1']
# Cargado: periodo54carrera8semestre3.csv en p54['p54c8s3']
# Cargado: periodo54carrera8semestre5.csv en p54['p54c8s5']
# Cargado: periodo54carrera8semestre7.csv en p54['p54c8s7']
# Cargado: periodo54carrera9semestre1.csv en p54['p54c9s1']
# Cargado: periodo54carrera9semestre3.csv en p54['p54c9s3']
# Cargado: periodo54carrera9semestre5.csv en p54['p54c9s5']
# Cargado: periodo54carrera9semestre6.csv en p54['p54c9s6']
# Cargado: periodo54carrera9semestre7.csv en p54['p54c9s7']
# Cargado: periodo55carrera10semestre1.csv en p55['p55c10s1']
# Cargado: periodo55carrera10semestre3.csv en p55['p55c10s3']
# Cargado: periodo55carrera10semestre5.csv en p55['p55c10s5']
# Cargado: periodo55carrera10semestre7.csv en p55['p55c10s7']
# 2024-2025A              47         197         217           6        252
# 2024-2025B              58         190         218           3        237
#
# Carrera_Nombre  Carrera 3  Carrera 4  Carrera 5  Carrera 6  Carrera 7  \
# Periodo_Nombre
# 2017-2018A            288        108        306         64         55
# 2017-2018B            271         84        302         58         50
# 2017-2018V             62         20         58          4          9
# 2018-2019A            239        100        304         63         62
# 2018-2019B            287        103        320         60         56
# 2018-2019V             75         29         77          0          7
# 2019-2020A            248         98        333         63         60
# 2019-2020B            268         98        347         59         67
# 2019-2020V             77         27         41          2          3
# 2020-2021A            253         81        355         64         57
# 2020-2021B            265         83        346         57         49
# 2020-2021V              9         12         17          9          0
# 2021-2022A            263         77        348         52         60
# 2021-2022B            271         74        296         53         56
# 2021-2022V             21         15         66          6          2
# 2022-2023A            220         72        326         36         53
# 2022-2023B            273         69        322         39         50
# 2022-2023V             44         12         31          1          4
# 2023-2024A            199         61        314         38         46
# 2023-2024B            230         57        320         35         52
# 2023-2024V             20          7          7          4          2
# 2024-2025A            195         61        329         42         41
# 2024-2025B            250         61        321         41         41
#
# Carrera_Nombre  Carrera 8  Carrera 9
# Periodo_Nombre
# 2017-2018A            201        374
# 2017-2018B            208        447
# 2017-2018V             28        111
# 2018-2019A            201        390
# 2018-2019B            236        442
# 2018-2019V             34         46
# 2019-2020A            202        357
# 2019-2020B            221        380
# 2019-2020V             30         70
# 2020-2021A            199        385
# 2020-2021B            202        418
# 2020-2021V             11         32
# 2021-2022A            198        310
# 2021-2022B            198        370
# 2021-2022V             39         50
# 2022-2023A            153        284
# 2022-2023B            176        306
# 2022-2023V             20         51
# 2023-2024A            137        301
# 2023-2024B            163        322
# 2023-2024V             14         34
# 2024-2025A            124        322
# 2024-2025B            113        328
#
# --- Estudiantes por Periodo, Carrera y Semestre (Primeros 5 registros) ---
#    Periodo_ID Periodo_Nombre Tipo_Periodo  Carrera_ID Carrera_Nombre  \
# 0          35     2017-2018A            A          10     Carrera 10
# 1          35     2017-2018A            A          10     Carrera 10
# 2          35     2017-2018A            A          10     Carrera 10
# 3          35     2017-2018A            A          10     Carrera 10
# 4          35     2017-2018A            A          10     Carrera 10
#
#    Semestre  Num_Estudiantes
# 0         1               35
# 1         3               14
# 2         5               10
# 3         7               10
# 4         9                8
#
# --- Distribución de Estudiantes por Semestre (Promedio en todos los periodos) ---
# Semestre
# 1     40.107383
# 2     51.208333
# 3     24.448276
# 4     34.408602
# 5     20.195312
# 6     28.075269
# 7     19.837838
# 8     26.546512
# 9     21.092784
# 10    24.802469
# Name: Num_Estudiantes, dtype: float64
#
# --- TOP 5 Carreras con más estudiantes (Promedio por periodo) ---
# Carrera_Nombre
# Carrera 9     6130
# Carrera 5     5486
# Carrera 3     4328
# Carrera 11    3266
# Carrera 2     3238
# Name: Num_Estudiantes, dtype: int64
#
# --- Estudiantes por Tipo de Periodo (A, B, V) ---
# Tipo_Periodo
# A    14584
# B    14877
# V     1912
# Name: Num_Estudiantes, dtype: int64
#
# Análisis de población completado.
